# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
songs_df = pd.read_csv("train_triplets.csv")

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59515 entries, 0 to 59514
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userid  59515 non-null  int64
#  1   songid  59515 non-null  int64
#  2   count   59515 non-null  int64
# dtypes: int64(3)
# memory usage: 1.4 MB

# %%
songs_df.head()
# Out:
#    userid  songid  count
# 0    2461    3450   2678
# 1    2299    2499   4987
# 2    4663    1056   3029
# 3    4532    1186   1297
# 4    3454    3809   2204

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
songs_df['count'].hist(ax=ax,bins=100)
ax.tick_params(labelsize=14)
ax.set_xlabel("Contagem de Plays", fontsize=14)
ax.set_ylabel("Quantidade", fontsize=14)
# Out:
# Text(0, 0.5, 'Quantidade')
